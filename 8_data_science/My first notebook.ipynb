# %% [markdown]
# # Title of your first notebook
# *Author: Paco Hulpiau*
#
# This first notebook introduces Jupyter notebooks in the Python scripting course

# %%
# Example-code-5-1
import os
# Some envirnoment variables
hostname = os.environ['HOSTNAME']
print("HOSTNAME: ", hostname)
print("USERNAME: ", os.environ['USERNAME'])
print("HOME DIR: ", os.environ['HOME'])
print("LANGUAGE: ", os.environ['LANG'])
print("PATH VAR: ", os.environ['PATH'])
# Out:
# HOSTNAME:  fedora
# USERNAME:  guest
# HOME DIR:  /home/guest
# LANGUAGE:  en_GB.UTF-8
# PATH VAR:  /home/guest/miniconda3/condabin:/home/guest/.local/bin:/home/guest/bin:/usr/local/bin:/usr/local/sbin:/usr/bin:/usr/sbin:/home/guest/Scripts:/home/guest/Scripts

# %%
os.environ['USERNAME']
os.environ['HOME']
# Out:
# '/home/guest'

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# anyio                     4.2.0
# argcomplete               2.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# Beaker                    1.12.1
# beautifulsoup4            4.12.2
# bleach                    6.1.0
# blivet                    3.7.1
# blivet-gui                2.4.2
# Brlapi                    0.8.4
# bs4                       0.0.1
# certifi                   2023.11.17
# cffi                      1.15.1
# chardet                   5.2.0
# charset-normalizer        3.1.0
# click                     8.1.3
# colorama                  0.4.6
# coloredlogs               15.0.1
# colormath                 3.0.0
# comm                      0.2.1
# configobj                 5.0.8
# contourpy                 1.2.0
# cryptography              37.0.2
# cupshelpers               1.0
# cycler                    0.12.1
# dasbus                    1.7
# dbus-python               1.3.2
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# distro                    1.8.0
# dnf                       4.18.2
# et-xmlfile                1.1.0
# eutils                    0.6.0
# executing                 2.0.1
# fastjsonschema            2.19.1
# fedora-third-party        0.10
# file-magic                0.4.0
# fonttools                 4.45.0
# fqdn                      1.5.1
# fros                      1.1
# future                    0.18.3
# gpg                       1.17.1
# humanfriendly             10.0
# humanize                  3.13.1
# idna                      3.4
# importlib-metadata        7.0.0
# ipykernel                 6.28.0
# ipython                   8.20.0
# isoduration               20.11.0
# jdcal                     1.4.1
# jedi                      0.19.1
# Jinja2                    3.1.2
# json5                     0.9.14
# jsonpointer               2.4
# jsonschema                4.20.0
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.0
# jupyter_core              5.7.1
# jupyter-events            0.9.0
# jupyter-lsp               2.2.1
# jupyter_server            2.12.2
# jupyter_server_terminals  0.5.1
# jupyterlab                4.0.10
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.25.2
# kiwisolver                1.4.5
# langtable                 0.0.64
# libcomps                  0.1.20
# libdnf                    0.72.0
# lxml                      4.9.2
# Mako                      1.2.3
# Markdown                  3.5.1
# markdown-it-py            3.0.0
# MarkupSafe                2.1.2
# matplotlib                3.8.2
# matplotlib-inline         0.1.6
# mdurl                     0.1.2
# mistune                   3.0.2
# mmtf-python               1.1.2
# msgpack                   1.0.4
# multiqc                   1.18
# mysqlclient               2.1.1
# nbclient                  0.9.0
# nbconvert                 7.14.0
# nbformat                  5.9.2
# nest-asyncio              1.5.8
# networkx                  3.2.1
# nftables                  0.1
# notebook                  7.0.6
# notebook_shim             0.2.3
# numpy                     1.24.4
# olefile                   0.46
# openpyxl                  3.0.10
# overrides                 7.4.0
# packaging                 23.0
# pandocfilters             1.5.0
# parso                     0.8.3
# Paste                     3.5.2
# pexpect                   4.8.0
# pid                       2.2.3
# Pillow                    9.5.0
# pip                       22.3.1
# platformdirs              4.1.0
# ply                       3.11
# Pmw                       2.1.1
# productmd                 1.37
# prometheus-client         0.19.0
# prompt-toolkit            3.0.43
# psutil                    5.9.5
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pwquality                 1.4.5
# pyaml-env                 1.2.1
# pycairo                   1.23.0
# pycparser                 2.20
# pycrypto                  2.6.1
# pycups                    2.0.1
# pycurl                    7.45.2
# pyenchant                 3.2.2
# Pygments                  2.17.2
# PyGObject                 3.44.2
# pykickstart               3.47
# pymol                     2.5.0
# pyOpenSSL                 21.0.0
# pyparsing                 3.1.1
# pyparted                  3.12.0
# PyQt4_sip                 4.19.25
# PySocks                   1.7.1
# python-augeas             1.1.0
# python-dateutil           2.8.2
# python-docx               1.1.0
# python-json-logger        2.0.7
# python-meh                0.51
# pytz                      2023.3.post1
# pyudev                    0.24.0
# pyxdg                     0.27
# PyYAML                    6.0
# pyzmq                     25.1.2
# referencing               0.32.1
# regex                     2023.10.3
# reportlab                 4.0.8
# requests                  2.31.0
# requests-file             1.5.1
# requests-ftp              0.3.1
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.7.0
# rich-click                1.7.2
# rpds-py                   0.16.2
# rpm                       4.18.2
# selinux                   3.5
# Send2Trash                1.8.2
# sepolicy                  3.5
# setools                   4.4.3
# setuptools                65.5.1
# shtab                     1.5.8
# simpleaudio               1.0.4
# simpleline                1.9.0
# six                       1.16.0
# sniffio                   1.3.0
# sos                       4.5.1
# soupsieve                 2.4.1
# spectra                   0.0.11
# stack-data                0.6.3
# systemd-python            235
# Tempita                   0.5.2
# termcolor                 1.1.0
# terminado                 0.18.0
# terminator                2.1.3
# tinycss2                  1.2.1
# tldr                      3.2.0
# tornado                   6.4
# traitlets                 5.14.1
# types-python-dateutil     2.8.19.20240106
# typing_extensions         4.5.0
# uri-template              1.3.0
# urllib3                   1.26.18
# wcwidth                   0.2.13
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.7.0
# wget                      3.2
# zipp                      3.17.0

# %%
# !locate urine.csv

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %ls
# Out:
#  biopython-cookbook.pdf*      'How fast are NumPy ops.ipynb'*
#  biopython-example.ipynb*      Marie.ipynb*
#  cov2_test.fasta*              mm10_dna.fasta*
# 'Data science part 1.ipynb'*  'My first notebook.ipynb'*
# 'Data science part 2.ipynb'*   NC_005816.gb*
